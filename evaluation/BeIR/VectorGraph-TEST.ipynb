# %%
import sys
import os

# move two directories up and make that current directory
os.chdir("../..")
# print current directory
print(os.getcwd())
# Out:
# /Users/chinmayshrivastava/Documents/GitHub/RepoStateManager

# %%
from modules.vectorgraph.VectorGraph import VectorGraph

vg = VectorGraph.from_persisting_dir(
    persisting_dir="deliverables/FMGlobal/index",
)
# Out:
# INFO:modules.vectorgraph.VectorGraph:Loading graph from persisting directory
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# INFO:modules.vectorgraph.VectorGraph:Graph loaded from deliverables/FMGlobal/index
# INFO:modules.vectorgraph.VectorGraph:Vector index loaded from deliverables/FMGlobal/index

# %%
vg.query_with_chunk_ids('What are the sprinkler recommendations for a 100,000 sq ft warehouse?')
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [(36,
# ...

# %%
# print the chunk numbers of the nodes in the graph vg.graph where cg.graph is a networkx graph
for node in vg.graph.nodes:
    if vg.graph.nodes[node]['type'] == 'chunk':
        print(vg.graph.nodes[node]['metadata'])
# Out:
# {'page_no': '1', 'file_type': 'application/pdf', 'chunk_no': 0}
# {'page_no': '1', 'file_type': 'application/pdf', 'chunk_no': 1}
# {'page_no': '1', 'file_type': 'application/pdf', 'chunk_no': 2}
# {'page_no': '2', 'file_type': 'application/pdf', 'chunk_no': 3}
# {'page_no': '2', 'file_type': 'application/pdf', 'chunk_no': 4}
# {'page_no': '2', 'file_type': 'application/pdf', 'chunk_no': 5}
# {'page_no': '2', 'file_type': 'application/pdf', 'chunk_no': 6}
# {'page_no': '3', 'file_type': 'application/pdf', 'chunk_no': 7}
# {'page_no': '3', 'file_type': 'application/pdf', 'chunk_no': 8}
# {'page_no': '3', 'file_type': 'application/pdf', 'chunk_no': 9}
# {'page_no': '3', 'file_type': 'application/pdf', 'chunk_no': 10}
# {'page_no': '4', 'file_type': 'application/pdf', 'chunk_no': 11}
# {'page_no': '5', 'file_type': 'application/pdf', 'chunk_no': 12}
# {'page_no': '5', 'file_type': 'application/pdf', 'chunk_no': 13}
# {'page_no': '5', 'file_type': 'application/pdf', 'chunk_no': 14}
# ...
